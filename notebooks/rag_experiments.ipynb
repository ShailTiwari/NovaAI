# %% [markdown]
# # RAG Experiments
#
# Use this notebook to try chunk sizes, retrieval counts, embedding models, and evaluation runs before changing the app.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path('..').resolve()
sys.path.insert(0, str(PROJECT_ROOT))
PROJECT_ROOT

# %% [markdown]
# ## Basic Evaluation
#
# Edit `data/eval/sample_qa.jsonl` so the questions and expected pages match the PDF you indexed. Then run the cell below with the same collection name and document ID used by the app.

# %%
from src.evaluation import run_basic_evaluation

collection_name = 'pdf_docs'  # replace with your Chroma collection
document_id = 'your_document_id_here'
qa_file = PROJECT_ROOT / 'data' / 'eval' / 'sample_qa.jsonl'

# report = run_basic_evaluation(collection_name, document_id, str(qa_file))
# report['metrics'], report['most_wrong_examples'][:3]
